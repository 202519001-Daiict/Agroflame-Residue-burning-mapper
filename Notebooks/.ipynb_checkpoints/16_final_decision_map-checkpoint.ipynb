# %% [markdown]
# # Notebook 16 — Final Decision Map
#
# **Purpose:** Combine BSI scores and recoverable residue to produce a three-tier bioenergy site-selection decision map.
#
# **Classification logic (70th percentile thresholds):**
# - **Plant Zone** — high BSI AND high residue → ideal biogas plant sites
# - **Policy Zone** — high BSI only → urgent burning-reduction policy target
# - **Low Priority** — below both thresholds → monitor
#
# **Input:** `Data/Processed/Punjab_Haryana_districts.gpkg`, `Data/Processed/bsi_scores.csv`, `Data/Processed/district_clusters.csv`, `Data/Processed/residue_calc.csv`
# **Output:** `Outputs/Maps/final_decision_map.png`

# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import os

os.makedirs('Outputs/Maps', exist_ok=True)

# ── Load all inputs ───────────────────────────────────────────────────────
districts = gpd.read_file('../Data/Processed/Punjab_Haryana_districts.gpkg')
bsi       = pd.read_csv('../Data/Processed/bsi_scores.csv')
clusters  = pd.read_csv('../Data/Processed/district_clusters.csv')
residue   = pd.read_csv('../Data/Processed/residue_calc.csv')

print("✅ All inputs loaded")
# Out:
# ✅ All inputs loaded

# %%
# ── Standardise district names ────────────────────────────────────────────
def clean(series):
    return series.str.replace(r'^\d+\.\s*', '', regex=True).str.strip().str.title()

districts['district'] = clean(districts['NAME_2'])
bsi['district']       = clean(bsi['district'])
clusters['district']  = clean(clusters['district'])
residue['district']   = clean(residue['district'])

# %%
# ── Aggregate residue to district level (mean across years) ───────────────
residue_district = (
    residue
    .groupby('district')['recoverable_t']
    .mean()
    .reset_index()
    .rename(columns={'recoverable_t': 'residue'})
)

# %%
# ── Merge everything into one GeoDataFrame ────────────────────────────────
gdf = (
    districts
    .merge(bsi,                              on='district', how='left')
    .merge(clusters[['district', 'zone']],   on='district', how='left')
    .merge(residue_district,                 on='district', how='left')
)

# Fill gaps
gdf['BSI']     = gdf['BSI'].fillna(0)
gdf['residue'] = gdf['residue'].fillna(gdf['residue'].median())
gdf['zone']    = gdf['zone'].fillna('Unknown')

print(f"Merged shape: {gdf.shape}")
print(gdf[['district', 'BSI', 'residue', 'zone']].head(8).to_string(index=False))
# Out:
# Merged shape: (43, 7)
#  district  BSI   residue                           zone
#    Ambala 38.6 150972.50 High Stress / High Opportunity
#   Bhiwani 61.5  84831.25                  Moderate Zone
# Faridabad 55.9  30616.25                  Moderate Zone
# Fatehabad 80.8 287857.50              Low Priority Zone
#  Gurugram 57.2  31456.25                  Moderate Zone
#     Hisar 77.0 255867.50              Low Priority Zone
#   Jhajjar 61.5 106688.75                  Moderate Zone
#      Jind 71.1 294901.25              Low Priority Zone

# %%
# ── Decision classification (70th-percentile thresholds) ─────────────────
# Using percentile thresholds rather than fixed values makes the
# classification relative to this study region, not dependent on
# absolute BSI / residue magnitudes.
bsi_thresh = gdf['BSI'].quantile(0.70)
res_thresh = gdf['residue'].quantile(0.70)

print(f"BSI threshold (p70)     : {bsi_thresh:.1f}")
print(f"Residue threshold (p70) : {res_thresh:,.0f} tonnes")

def classify_zone(row):
    high_bsi     = row['BSI']     >= bsi_thresh
    high_residue = row['residue'] >= res_thresh
    if   high_bsi and high_residue: return 'Plant Zone'
    elif high_bsi:                   return 'Policy Zone'
    else:                            return 'Low Priority'

gdf['final_zone'] = gdf.apply(classify_zone, axis=1)

print("\nFinal zone distribution:")
print(gdf['final_zone'].value_counts().to_string())
# Out:
# BSI threshold (p70)     : 71.2
# Residue threshold (p70) : 230,152 tonnes
#
# Final zone distribution:
# final_zone
# Low Priority    30
# Plant Zone       9
# Policy Zone      4

# %%
# ── Final decision map ────────────────────────────────────────────────────
final_palette = {
    'Plant Zone'  : '#d62828',   # red   — highest priority for plant investment
    'Policy Zone' : '#f77f00',   # orange — burning-reduction policy focus
    'Low Priority': '#adb5bd',   # grey   — monitor only
}
gdf['color'] = gdf['final_zone'].map(final_palette)

fig, ax = plt.subplots(figsize=(10, 9))
gdf.plot(color=gdf['color'], edgecolor='black', linewidth=0.5, ax=ax)

for _, row in gdf.iterrows():
    c = row.geometry.centroid
    ax.annotate(row['district'], xy=(c.x, c.y), fontsize=4, ha='center', color='#111111')

patches = [
    mpatches.Patch(color=c, label=z)
    for z, c in final_palette.items()
]
ax.legend(handles=patches, title='Decision Zone', loc='lower right',
          fontsize=9, framealpha=0.9)
ax.set_title('Bioenergy Plant Site Selection — Final Decision Map',
             fontsize=13, fontweight='bold')
ax.axis('off')

plt.tight_layout()
plt.savefig('../Outputs/Maps/final_decision_map.png', dpi=300, bbox_inches='tight')
plt.show()
print("✅ Saved: Outputs/Maps/final_decision_map.png")
# Out:
# ✅ Saved: Outputs/Maps/final_decision_map.png

# %%
# ── Summary table ─────────────────────────────────────────────────────────
summary = (
    gdf[['district', 'BSI', 'residue', 'zone', 'final_zone']]
    .sort_values('BSI', ascending=False)
    .reset_index(drop=True)
)

print("\nFull district decision table:")
print(summary.to_string(index=False))
# Out:
# Full district decision table:
#        district   BSI       residue                           zone   final_zone
#         Sangrur 100.0 421316.134615              Low Priority Zone   Plant Zone
#        Bathinda  95.1 312282.519231              Low Priority Zone   Plant Zone
#         Muktsar  90.0 265920.711538              Low Priority Zone   Plant Zone
#         Fazilka  88.5 227997.954545              Low Priority Zone  Policy Zone
#           Sirsa  84.4 304351.250000              Low Priority Zone   Plant Zone
#       Ferozepur  83.0 167376.865385              Low Priority Zone  Policy Zone
#       Fatehabad  80.8 287857.500000              Low Priority Zone   Plant Zone
#            Moga  80.6 257343.288462              Low Priority Zone   Plant Zone
#           Mansa  78.0 206754.692308              Low Priority Zone  Policy Zone
#           Hisar  77.0 255867.500000              Low Priority Zone   Plant Zone
# ...
